# %% [markdown]
# ## Data Visualization Seaborn

# %%
# %pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## create a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("tips vs bill")
plt.show()

# %%
## line plot

sns.lineplot(x='size',y='total_bill',data=tips)
plt.title('line plot of total bill by size')
plt.show()

# %%
## categorical plot
#3 bar plot
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar plot of categorical data')
plt.show()

# %%
## bow plot
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title('box plot of categorical data')
plt.show()

# %%
sns.boxenplot(x='day',y='total_bill',data=tips)
plt.title('boxen plot of categorical data')
plt.show()

# %%
## violent plot

sns.violinplot(x='day',y='total_bill',data=tips)
plt.title('voilent graph of day and bill')
# Out:
# Text(0.5, 1.0, 'voilent graph of day and bill')

# %%
## histogram

sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(tips['total_bill'],shade=True)
# Out:
# C:\Users\Keshavraj\AppData\Local\Temp\ipykernel_20736\3986565792.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'],shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## pairplot
sns.pairplot(tips)

# %%
## heatmap

corr=tips[['total_bill','tip','size']].corr()

# %%
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
empinfo=pd.read_csv('employee_info.csv')
empinfo.head()
# Out:
#              name                     Email                   Phone  \
# 0  Brandy Burnett  judymckinney@example.org  001-648-973-2174x79557
# 1    David Pierce      stacey62@example.net            729-498-9566
# 2    Desiree Luna     william53@example.com         +1-560-991-3531
# 3     Erika Young   curtiskevin@example.com            465-894-0663
# 4  Gregory Harris   triciastark@example.com            348.427.6831
#
#   date_of_birth                                            Address  \
# 0    2008-06-02          61935 Esparza Ridge\nBentonbury, MA 74474
# 1    1972-05-19                          USCGC Walsh\nFPO AA 67225
# 2    2001-07-29     746 Colleen Junctions\nMartinezhaven, LA 71949
# 3    1911-10-28  5833 Hernandez River Suite 159\nNew Robertfort...
# 4    1964-08-15  216 Lisa Ridges Apt. 227\nEast Kaylaside, PW 8...
#
#                                  job    credit_card_no           country
# 0                       Bonds trader      676375554380  French Polynesia
# ...

# %%
## Average income by country

plt.figure(figsize=(10,6))
sns.barplot(x="country",y="credit_card_no",data=empinfo,estimator=sum)
# Out:
# <Axes: xlabel='country', ylabel='credit_card_no'>
